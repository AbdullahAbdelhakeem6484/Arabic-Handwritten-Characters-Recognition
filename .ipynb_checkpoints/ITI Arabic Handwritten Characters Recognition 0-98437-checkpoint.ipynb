png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/00085.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/11870.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/07602.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/04283.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/02388.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/05371.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/01059.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/00551.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/04379.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/12088.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/04106.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/13125.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/02057.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/08550.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/03105.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/03840.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/07104.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/09100.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/07345.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/06457.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/07420.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/08635.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/01168.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/05496.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/03820.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/10068.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/10503.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/12452.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/03753.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/04073.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/10609.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/11198.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/12419.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/04625.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/12332.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/03393.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/10354.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/07764.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/12823.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/07823.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/09667.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/05777.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/08490.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/06509.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/00472.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/03819.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/10645.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/02244.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/08985.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/04406.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/12737.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/07238.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/09335.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/06697.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/07120.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/00053.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/06600.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/08568.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/04238.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/08069.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/08398.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/06395.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/00893.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/00831.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/13098.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/01599.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/01084.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/10470.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/08888.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/13121.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/02623.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/11062.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/10835.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/11471.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/10837.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/06856.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/05243.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/03563.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/04446.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/05137.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/07979.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/07551.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/08510.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/02980.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/10640.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/05087.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/09599.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/02267.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/01904.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/00825.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/12380.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/06462.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/03737.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/11931.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/01551.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/08977.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/09319.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/01627.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/05639.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/12122.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/07443.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/13074.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/06384.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/01201.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/03133.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/05092.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/01214.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/00890.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/02819.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/02890.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/07703.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/07165.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/08178.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/02556.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/05155.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/05525.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/06692.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/12815.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/05053.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/00732.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/11011.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/11338.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/10407.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/04897.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/07978.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/02408.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/04383.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/01424.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/02827.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/12689.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/08604.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/00233.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/13100.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/12038.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/03935.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/08830.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/02285.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/02349.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/03282.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/00872.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/07617.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/02714.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/13027.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/08906.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/01083.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/10472.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/11923.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/03937.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/05017.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/00908.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/07664.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/08999.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/03158.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/06089.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/01148.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/05466.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/02803.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/02590.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/01780.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/10617.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/03432.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/06459.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/01474.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/02210.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/04445.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/04563.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/02739.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/00291.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/08944.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/03152.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/07818.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/09061.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/11733.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/07903.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/04741.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/08745.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/13283.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/01982.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/09232.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/04356.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/12060.png
# /kaggle/input/arabic-hwr-ai-pro-intake1/train/01632.png

# %%
## Most Important
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from pathlib import Path
from PIL import Image

## less Important
from functools import partial
import os
from scipy import stats
import missingno as msno
import joblib
import tarfile
import shutil
import urllib

## Sklearn
from sklearn import datasets
## Preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
## Metrics
from sklearn.metrics import accuracy_score

## tensorflow & Keras
import tensorflow as tf    ## i will use tf for every thing and for keras using tf.keras

# %% [markdown]
# ## Loading the Data and Look at the Big Picture

# %% [markdown]
# `Only for training here`

# %%
train_labels = pd.read_csv('../input/arabic-hwr-ai-pro-intake1/train.csv')
train_images = Path(r'../input/arabic-hwr-ai-pro-intake1/train')

## read these all training images paths as Series
train_images_paths = pd.Series(sorted(list(train_images.glob(r'*.png'))), name='Filepath').astype(str)

train_images_paths.head()
# Out:
# 0    ../input/arabic-hwr-ai-pro-intake1/train/00000...
# 1    ../input/arabic-hwr-ai-pro-intake1/train/00001...
# 2    ../input/arabic-hwr-ai-pro-intake1/train/00002...
# 3    ../input/arabic-hwr-ai-pro-intake1/train/00003...
# 4    ../input/arabic-hwr-ai-pro-intake1/train/00004...
# Name: Filepath, dtype: object

# %% [markdown]
# ## Explore the Data

# %%
img_key_value = {}
for value in train_labels['label'].unique():
    img_key_value[value] = train_labels[train_labels['label']==value].index[0]
    
img_index = list(img_key_value.values())
img_label = list(img_key_value.keys())

fig, ax = plt.subplots(4, 7, figsize=(12, 8))

i = 0
for row in range(4):
    for col in range(7):
        plt.sca(ax[row, col])
        plt.title(f'label = {img_label[i]}')
        img = plt.imread(train_images_paths.iloc[img_index[i]])
        plt.imshow(img)
        plt.axis('off')
        i+=1

# %%
print('Number of Instances in train_set =>', len(train_images_paths))
print('Number of Instances in train_labels =>', len(train_labels))

print()

img = plt.imread(train_images_paths.iloc[img_index[0]])
print('shape of each Image is =>', img.shape)
# Out:
# Number of Instances in train_set => 13440
# Number of Instances in train_labels => 13440
#
# shape of each Image is => (32, 32, 4)

# %% [markdown]
# ## Data Preprocessing

# %%
train_full_labels = train_labels['label'].values
train_full_set = np.empty((13440, 32, 32, 3), dtype=np.float32)  #take only the first 3 channels

for idx, path in enumerate(train_images_paths):
    img = plt.imread(path)
    img = img[:,:,:3]
    train_full_set[idx] = img
    
print('train_full_set.shape =>', train_full_set.shape)
print('train_full_labels.shape =>', train_full_labels.shape)
# Out:
# train_full_set.shape => (13440, 32, 32, 3)
# train_full_labels.shape => (13440,)

# %% [markdown]
# ## Split the Data

# %%
X_train, X_valid, y_train, y_valid = train_test_split(train_full_set, train_full_labels, 
                                                      test_size=0.2, shuffle=True, random_state=42)

print('X_train.shape =>', X_train.shape)
print('X_valid.shape =>', X_valid.shape)
print('y_train.shape =>', y_train.shape)
print('y_valid.shape =>', y_valid.shape)
# Out:
# X_train.shape => (10752, 32, 32, 3)
# X_valid.shape => (2688, 32, 32, 3)
# y_train.shape => (10752,)
# y_valid.shape => (2688,)

# %% [markdown]
# ## Model Training

# %%
from tensorflow.keras.models import Sequential
from tensorflow. keras. layers import Dense, Dropout, Flatten, Conv2D,MaxPooling2D,BatchNormalization
from tensorflow.keras import backend as K
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16, MobileNet,MobileNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D,AveragePooling2D
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam, Adadelta
import matplotlib.pyplot as plt
from keras.utils.vis_utils import plot_model
from keras.callbacks import LearningRateScheduler,ReduceLROnPlateau

# %%
input_shape=(32,32,3)
num_classes=29
batch_size = 128 # Handle 128 pictures at each round
epochs = 100

# %%
def model_cnn1(input_shape=input_shape,num_classes=num_classes):   
    model = Sequential()

    # Add convolutional layer consisting of 32 filters and shape of 3x3 with ReLU activation
    # We want to preserve more information for following layers so we use padding
    # 'Same' padding tries to pad evenly left and right, 
    # but if the amount of columns to be added is odd, it will add the extra column to the right
    model.add(Conv2D(32, kernel_size = (3,3), activation='relu', input_shape = input_shape))
    model.add(BatchNormalization())
    model.add(Conv2D(32, kernel_size = (3,3), activation='relu'))
    model.add(BatchNormalization())

    # Add convolutional layer consisting of 32 filters and shape of 5x5 with ReLU activation
    # We give strides=2 for space between each sample on the pixel grid
    model.add(Conv2D(32, kernel_size = (5,5), strides=2, padding='same', activation='relu'))
    model.add(BatchNormalization())
    # Dropping %40 of neurons
    model.add(Dropout(0.4))
    
    model.add(Conv2D(64, kernel_size = (3,3), activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(64, kernel_size = (3,3), activation='relu'))
    model.add(BatchNormalization())
    model.add(Conv2D(64, kernel_size = (5,5), strides=2, padding='same', activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))
    
    model.add(Conv2D(128, kernel_size = 4, activation='relu'))
    model.add(BatchNormalization())
    # To be able to merge into fully connected layer we have to flatten
    model.add(Flatten())
    model.add(Dropout(0.4))
    # Lets add softmax activated neurons as much as number of classes
    model.add(Dense(num_classes, activation = "softmax"))
    # Compile the model with loss and metrics
    model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])
    
    return model

# %%
def model_cnn2(input_shape=input_shape,num_classes=num_classes): 
    model = Sequential()
    model.add(Conv2D(64, kernel_size=(2, 2), strides=(1, 1), activation='relu', input_shape=input_shape))
    model.add(BatchNormalization())

    model.add(Conv2D(128, kernel_size=(4, 4), strides=(1, 1), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(256, kernel_size=(4, 4), strides=(1, 1), activation='relu', padding='same'))
    model.add(BatchNormalization())

    model.add(Conv2D(512, kernel_size=(4, 4), strides=(1, 1), activation='relu', padding='same'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Flatten())

    # model.add(Dense(512, activation='elu'))
    # model.add(BatchNormalization())
    # model.add(Dropout(droprate))

    # model.add(Dense(256, activation='elu'))
    # model.add(BatchNormalization())
    # model.add(Dropout(droprate))

    model.add(Dense(512, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    model.add(Dense(num_classes, activation='softmax'))

    model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])
    return model

# %%
def LeNet5(input_shape=input_shape,num_classes=num_classes):
    model = Sequential()
    model.add(Conv2D(6, kernel_size=(5, 5), strides=(1, 1), activation='relu', input_shape=input_shape, padding="same"))
    model.add(AveragePooling2D(pool_size=(2, 2), strides=(1, 1), padding='valid'))
    model.add(Conv2D(16, kernel_size=(5, 5), strides=(1, 1), activation='relu', padding='valid'))
    model.add(AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='valid'))
    model.add(Conv2D(120, kernel_size=(5, 5), strides=(1, 1), activation='relu', padding='valid'))
    model.add(Flatten())
    model.add(Dense(84, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])
    return model

# %%
# num_classes = 29
# img_rows, img_cols = 32,32
# droprate = 0.25
# # MODEL
# input_shape = (img_rows, img_cols, 3)
# model = Sequential()
# model.add(Conv2D(64, kernel_size=(2, 2), strides=(1, 1), activation='relu', input_shape=input_shape))
# model.add(BatchNormalization())

# model.add(Conv2D(128, kernel_size=(4, 4), strides=(1, 1), activation='relu', padding='same'))
# model.add(BatchNormalization())
# model.add(MaxPooling2D(pool_size=(2, 2)))

# model.add(Conv2D(256, kernel_size=(4, 4), strides=(1, 1), activation='relu', padding='same'))
# model.add(BatchNormalization())

# model.add(Conv2D(512, kernel_size=(4, 4), strides=(1, 1), activation='relu', padding='same'))
# model.add(BatchNormalization())
# model.add(Dropout(droprate))
# model.add(Flatten())

# # model.add(Dense(512, activation='elu'))
# # model.add(BatchNormalization())
# # model.add(Dropout(droprate))

# # model.add(Dense(256, activation='elu'))
# # model.add(BatchNormalization())
# # model.add(Dropout(droprate))

# model.add(Dense(512, activation='relu'))
# model.add(BatchNormalization())
# model.add(Dropout(droprate))
# model.add(Dense(num_classes, activation='softmax'))

# model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# %%
print("My Custom CNN Network1:")
plot_model(model_cnn1(), to_file='custom-cnn1.png', show_shapes=True, show_layer_names=True)
# Out:
# My Custom CNN Network1:
# 2021-11-07 23:58:45.004285: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-07 23:58:45.125574: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-07 23:58:45.126418: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-07 23:58:45.127812: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-11-07 23:58:45.128904: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-07 23:58:45.129685: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-07 23:58:45.130401: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-07 23:58:46.887226: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-07 23:58:46.888026: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-07 23:58:46.888676: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-07 23:58:46.889259: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
print("My Custom CNN Network2:")
plot_model(model_cnn2(), to_file='custom-cnn2.png', show_shapes=True, show_layer_names=True)
# Out:
# My Custom CNN Network2:

# %%
print("Master Yann LeCun's LeNet-5 Network:")
plot_model(LeNet5(), to_file='lenet-5.png', show_shapes=True, show_layer_names=True)
# Out:
# Master Yann LeCun's LeNet-5 Network:

# %%
model = []
model.append(model_cnn1())
model.append(model_cnn2())
model.append(LeNet5())

# %%
datagen = ImageDataGenerator(rotation_range=10, zoom_range = 0.1, width_shift_range=0.1, height_shift_range=0.1)
datagen.fit(X_train)

# %%
models = []
for i in range(len(model)):
    model[i].fit_generator(datagen.flow(X_train,y_train, batch_size=batch_size),
                                        epochs = epochs, steps_per_epoch=X_train.shape[0] // batch_size,
                                        validation_data = (X_valid, y_valid), 
                                        callbacks=[ReduceLROnPlateau(monitor='loss', patience=3, factor=0.1)], 
                                        verbose=2)
    models.append(model[i])
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 2021
- val_accuracy: 0.0000e+00
# Epoch 3/100
# 84/84 - 8s - loss: 0.3397 - accuracy: 0.8987 - val_loss: 507.7868 - val_accuracy: 0.0335
# Epoch 4/100
# 84/84 - 8s - loss: 0.2351 - accuracy: 0.9289 - val_loss: 1263.9197 - val_accuracy: 0.0335
# Epoch 5/100
# 84/84 - 8s - loss: 0.1957 - accuracy: 0.9382 - val_loss: 1783.6420 - val_accuracy: 0.0335
# Epoch 6/100
# 84/84 - 8s - loss: 0.1974 - accuracy: 0.9411 - val_loss: 170.2500 - val_accuracy: 0.0327
# Epoch 7/100
# 84/84 - 8s - loss: 0.1477 - accuracy: 0.9530 - val_loss: 168.0142 - val_accuracy: 0.0420
# Epoch 8/100
# 84/84 - 8s - loss: 0.1173 - accuracy: 0.9634 - val_loss: 105.5667 - val_accuracy: 0.0428
# Epoch 9/100
# 84/84 - 8s - loss: 0.1096 - accuracy: 0.9662 - val_loss: 0.2550 - val_accuracy: 0.9241
# Epoch 10/100
# 84/84 - 8s - loss: 0.0955 - accuracy: 0.9709 - val_loss: 0.2180 - val_accuracy: 0.9334
# Epoch 11/100
# 84/84 - 8s - loss: 0.0897 - accuracy: 0.9725 - val_loss: 1.1395 - val_accuracy: 0.6901
# Epoch 12/100
# 84/84 - 8s - loss: 0.0764 - accuracy: 0.9766 - val_loss: 2.9645 - val_accuracy: 0.4423
# Epoch 13/100
# 84/84 - 8s - loss: 0.0796 - accuracy: 0.9761 - val_loss: 0.1921 - val_accuracy: 0.9327
# Epoch 14/100
# 84/84 - 8s - loss: 0.0738 - accuracy: 0.9773 - val_loss: 0.1772 - val_accuracy: 0.9472
# Epoch 15/100
# 84/84 - 8s - loss: 0.0757 - accuracy: 0.9778 - val_loss: 4.2527 - val_accuracy: 0.3940
# Epoch 16/100
# 84/84 - 8s - loss: 0.0623 - accuracy: 0.9801 - val_loss: 0.3938 - val_accuracy: 0.8531
# Epoch 17/100
# 84/84 - 8s - loss: 0.0581 - accuracy: 0.9822 - val_loss: 0.1928 - val_accuracy: 0.9334
# Epoch 18/100
# 84/84 - 8s - loss: 0.0569 - accuracy: 0.9834 - val_loss: 5.1707 - val_accuracy: 0.2749
# Epoch 19/100
# 84/84 - 8s - loss: 0.0540 - accuracy: 0.9832 - val_loss: 0.2116 - val_accuracy: 0.9405
# Epoch 20/100
# 84/84 - 8s - loss: 0.0518 - accuracy: 0.9834 - val_loss: 0.3113 - val_accuracy: 0.8955
# Epoch 21/100
# 84/84 - 9s - loss: 0.0577 - accuracy: 0.9817 - val_loss: 10.4081 - val_accuracy: 0.2307
# Epoch 22/100
# 84/84 - 8s - loss: 0.0490 - accuracy: 0.9847 - val_loss: 0.1257 - val_accuracy: 0.9673
# Epoch 23/100
# 84/84 - 8s - loss: 0.0577 - accuracy: 0.9821 - val_loss: 12.8891 - val_accuracy: 0.2031
# Epoch 24/100
# 84/84 - 8s - loss: 0.0448 - accuracy: 0.9867 - val_loss: 0.1400 - val_accuracy: 0.9624
# Epoch 25/100
# 84/84 - 9s - loss: 0.0522 - accuracy: 0.9829 - val_loss: 0.7952 - val_accuracy: 0.7645
# Epoch 26/100
# 84/84 - 8s - loss: 0.0457 - accuracy: 0.9852 - val_loss: 0.1473 - val_accuracy: 0.9647
# Epoch 27/100
# 84/84 - 8s - loss: 0.0453 - accuracy: 0.9867 - val_loss: 8.8009 - val_accuracy: 0.4141
# Epoch 28/100
# 84/84 - 8s - loss: 0.0311 - accuracy: 0.9897 - val_loss: 0.0846 - val_accuracy: 0.9773
# Epoch 29/100
# 84/84 - 8s - loss: 0.0259 - accuracy: 0.9927 - val_loss: 0.0671 - val_accuracy: 0.9810
# Epoch 30/100
# 84/84 - 8s - loss: 0.0220 - accuracy: 0.9933 - val_loss: 0.0661 - val_accuracy: 0.9829
# Epoch 31/100
# 84/84 - 8s - loss: 0.0189 - accuracy: 0.9944 - val_loss: 0.0667 - val_accuracy: 0.9833
# Epoch 32/100
# 84/84 - 8s - loss: 0.0194 - accuracy: 0.9943 - val_loss: 0.0657 - val_accuracy: 0.9833
# Epoch 33/100
# 84/84 - 8s - loss: 0.0168 - accuracy: 0.9956 - val_loss: 0.0686 - val_accuracy: 0.9825
# Epoch 34/100
# 84/84 - 8s - loss: 0.0141 - accuracy: 0.9959 - val_loss: 0.0664 - val_accuracy: 0.9833
# Epoch 35/100
# 84/84 - 8s - loss: 0.0156 - accuracy: 0.9957 - val_loss: 0.0639 - val_accuracy: 0.9836
# Epoch 36/100
# 84/84 - 8s - loss: 0.0141 - accuracy: 0.9963 - val_loss: 0.0736 - val_accuracy: 0.9814
# Epoch 37/100
# 84/84 - 8s - loss: 0.0123 - accuracy: 0.9966 - val_loss: 0.0754 - val_accuracy: 0.9810
# Epoch 38/100
# 84/84 - 8s - loss: 0.0136 - accuracy: 0.9964 - val_loss: 0.0780 - val_accuracy: 0.9814
# Epoch 39/100
# 84/84 - 8s - loss: 0.0126 - accuracy: 0.9965 - val_loss: 0.0672 - val_accuracy: 0.9818
# Epoch 40/100
# 84/84 - 8s - loss: 0.0126 - accuracy: 0.9967 - val_loss: 0.0627 - val_accuracy: 0.9829
# Epoch 41/100
# 84/84 - 8s - loss: 0.0122 - accuracy: 0.9963 - val_loss: 0.0654 - val_accuracy: 0.9836
# Epoch 42/100
# 84/84 - 8s - loss: 0.0094 - accuracy: 0.9974 - val_loss: 0.0662 - val_accuracy: 0.9818
# Epoch 43/100
# 84/84 - 8s - loss: 0.0100 - accuracy: 0.9968 - val_loss: 0.0679 - val_accuracy: 0.9818
# Epoch 44/100
# 84/84 - 8s - loss: 0.0098 - accuracy: 0.9968 - val_loss: 0.0678 - val_accuracy: 0.9818
# Epoch 45/100
# 84/84 - 8s - loss: 0.0105 - accuracy: 0.9965 - val_loss: 0.0677 - val_accuracy: 0.9825
# Epoch 46/100
# 84/84 - 8s - loss: 0.0093 - accuracy: 0.9978 - val_loss: 0.0676 - val_accuracy: 0.9825
# Epoch 47/100
# 84/84 - 8s - loss: 0.0106 - accuracy: 0.9972 - val_loss: 0.0679 - val_accuracy: 0.9821
# Epoch 48/100
# 84/84 - 8s - loss: 0.0098 - accuracy: 0.9976 - val_loss: 0.0679 - val_accuracy: 0.9821
# Epoch 49/100
# 84/84 - 8s - loss: 0.0093 - accuracy: 0.9973 - val_loss: 0.0679 - val_accuracy: 0.9825
# Epoch 50/100
# 84/84 - 8s - loss: 0.0110 - accuracy: 0.9968 - val_loss: 0.0678 - val_accuracy: 0.9821
# Epoch 51/100
# 84/84 - 8s - loss: 0.0108 - accuracy: 0.9969 - val_loss: 0.0679 - val_accuracy: 0.9821
# Epoch 52/100
# 84/84 - 8s - loss: 0.0101 - accuracy: 0.9974 - val_loss: 0.0679 - val_accuracy: 0.9821
# Epoch 53/100
# 84/84 - 8s - loss: 0.0086 - accuracy: 0.9980 - val_loss: 0.0680 - val_accuracy: 0.9821
# Epoch 54/100
# 84/84 - 8s - loss: 0.0085 - accuracy: 0.9978 - val_loss: 0.0679 - val_accuracy: 0.9825
# Epoch 55/100
# 84/84 - 8s - loss: 0.0103 - accuracy: 0.9967 - val_loss: 0.0679 - val_accuracy: 0.9821
# Epoch 56/100
# 84/84 - 9s - loss: 0.0111 - accuracy: 0.9967 - val_loss: 0.0679 - val_accuracy: 0.9821
# Epoch 57/100
# 84/84 - 8s - loss: 0.0097 - accuracy: 0.9977 - val_loss: 0.0679 - val_accuracy: 0.9825
# Epoch 58/100
# 84/84 - 8s - loss: 0.0090 - accuracy: 0.9977 - val_loss: 0.0679 - val_accuracy: 0.9821
# Epoch 59/100
# 84/84 - 8s - loss: 0.0107 - accuracy: 0.9976 - val_loss: 0.0679 - val_accuracy: 0.9821
# Epoch 60/100
# 84/84 - 8s - loss: 0.0093 - accuracy: 0.9978 - val_loss: 0.0680 - val_accuracy: 0.9821
# Epoch 61/100
# 84/84 - 8s - loss: 0.0109 - accuracy: 0.9971 - val_loss: 0.0679 - val_accuracy: 0.9821
# Epoch 62/100
# 84/84 - 8s - loss: 0.0111 - accuracy: 0.9970 - val_loss: 0.0679 - val_accuracy: 0.9821
# Epoch 63/100
# 84/84 - 8s - loss: 0.0113 - accuracy: 0.9965 - val_loss: 0.0681 - val_accuracy: 0.9818
# Epoch 64/100
# 84/84 - 8s - loss: 0.0092 - accuracy: 0.9976 - val_loss: 0.0681 - val_accuracy: 0.9825
# Epoch 65/100
# 84/84 - 8s - loss: 0.0097 - accuracy: 0.9974 - val_loss: 0.0679 - val_accuracy: 0.9825
# Epoch 66/100
# 84/84 - 8s - loss: 0.0096 - accuracy: 0.9979 - val_loss: 0.0678 - val_accuracy: 0.9825
# Epoch 67/100
# 84/84 - 8s - loss: 0.0098 - accuracy: 0.9978 - val_loss: 0.0680 - val_accuracy: 0.9821
# Epoch 68/100
# 84/84 - 8s - loss: 0.0106 - accuracy: 0.9973 - val_loss: 0.0679 - val_accuracy: 0.9821
# Epoch 69/100
# 84/84 - 8s - loss: 0.0099 - accuracy: 0.9974 - val_loss: 0.0681 - val_accuracy: 0.9825
# Epoch 70/100
# 84/84 - 8s - loss: 0.0107 - accuracy: 0.9962 - val_loss: 0.0680 - val_accuracy: 0.9825
# Epoch 71/100
# 84/84 - 8s - loss: 0.0092 - accuracy: 0.9980 - val_loss: 0.0680 - val_accuracy: 0.9821
# Epoch 72/100
# 84/84 - 8s - loss: 0.0113 - accuracy: 0.9976 - val_loss: 0.0679 - val_accuracy: 0.9821
# Epoch 73/100
# 84/84 - 8s - loss: 0.0117 - accuracy: 0.9971 - val_loss: 0.0680 - val_accuracy: 0.9821
# Epoch 74/100
# 84/84 - 8s - loss: 0.0100 - accuracy: 0.9970 - val_loss: 0.0681 - val_accuracy: 0.9821
# Epoch 75/100
# 84/84 - 8s - loss: 0.0100 - accuracy: 0.9975 - val_loss: 0.0681 - val_accuracy: 0.9818
# Epoch 76/100
# 84/84 - 8s - loss: 0.0117 - accuracy: 0.9968 - val_loss: 0.0679 - val_accuracy: 0.9818
# Epoch 77/100
# 84/84 - 8s - loss: 0.0119 - accuracy: 0.9967 - val_loss: 0.0680 - val_accuracy: 0.9821
# Epoch 78/100
# 84/84 - 8s - loss: 0.0116 - accuracy: 0.9963 - val_loss: 0.0681 - val_accuracy: 0.9821
# Epoch 79/100
# 84/84 - 8s - loss: 0.0111 - accuracy: 0.9969 - val_loss: 0.0680 - val_accuracy: 0.9821
# Epoch 80/100
# 84/84 - 8s - loss: 0.0106 - accuracy: 0.9971 - val_loss: 0.0681 - val_accuracy: 0.9821
# Epoch 81/100
# 84/84 - 8s - loss: 0.0101 - accuracy: 0.9972 - val_loss: 0.0682 - val_accuracy: 0.9825
# Epoch 82/100
# 84/84 - 8s - loss: 0.0102 - accuracy: 0.9976 - val_loss: 0.0681 - val_accuracy: 0.9825
# Epoch 83/100
# 84/84 - 8s - loss: 0.0106 - accuracy: 0.9971 - val_loss: 0.0681 - val_accuracy: 0.9821
# Epoch 84/100
# 84/84 - 8s - loss: 0.0100 - accuracy: 0.9974 - val_loss: 0.0682 - val_accuracy: 0.9818
# Epoch 85/100
# 84/84 - 8s - loss: 0.0124 - accuracy: 0.9964 - val_loss: 0.0681 - val_accuracy: 0.9821
# Epoch 86/100
# 84/84 - 8s - loss: 0.0104 - accuracy: 0.9973 - val_loss: 0.0680 - val_accuracy: 0.9825
# Epoch 87/100
# 84/84 - 8s - loss: 0.0096 - accuracy: 0.9981 - val_loss: 0.0679 - val_accuracy: 0.9825
# Epoch 88/100
# 84/84 - 8s - loss: 0.0110 - accuracy: 0.9972 - val_loss: 0.0679 - val_accuracy: 0.9825
# Epoch 89/100
# 84/84 - 8s - loss: 0.0106 - accuracy: 0.9966 - val_loss: 0.0679 - val_accuracy: 0.9825
# Epoch 90/100
# 84/84 - 8s - loss: 0.0098 - accuracy: 0.9965 - val_loss: 0.0680 - val_accuracy: 0.9825
# Epoch 91/100
# 84/84 - 8s - loss: 0.0102 - accuracy: 0.9971 - val_loss: 0.0679 - val_accuracy: 0.9825
# Epoch 92/100
# 84/84 - 8s - loss: 0.0097 - accuracy: 0.9977 - val_loss: 0.0680 - val_accuracy: 0.9825
# Epoch 93/100
# 84/84 - 8s - loss: 0.0098 - accuracy: 0.9977 - val_loss: 0.0680 - val_accuracy: 0.9818
# Epoch 94/100
# 84/84 - 8s - loss: 0.0104 - accuracy: 0.9969 - val_loss: 0.0680 - val_accuracy: 0.9825
# Epoch 95/100
# 84/84 - 8s - loss: 0.0108 - accuracy: 0.9966 - val_loss: 0.0681 - val_accuracy: 0.9825
# Epoch 96/100
# 84/84 - 8s - loss: 0.0112 - accuracy: 0.9962 - val_loss: 0.0680 - val_accuracy: 0.9825
# Epoch 97/100
# 84/84 - 8s - loss: 0.0100 - accuracy: 0.9971 - val_loss: 0.0679 - val_accuracy: 0.9821
# Epoch 98/100
# 84/84 - 8s - loss: 0.0099 - accuracy: 0.9975 - val_loss: 0.0679 - val_accuracy: 0.9821
# Epoch 99/100
# 84/84 - 8s - loss: 0.0107 - accuracy: 0.9967 - val_loss: 0.0680 - val_accuracy: 0.9821
# Epoch 100/100
# 84/84 - 8s - loss: 0.0110 - accuracy: 0.9973 - val_loss: 0.0679 - val_accuracy: 0.9821
# Epoch 1/100
# 84/84 - 5s - loss: 2.6508 - accuracy: 0.2152 - val_loss: 1.4367 - val_accuracy: 0.5398
# Epoch 2/100
# 84/84 - 5s - loss: 1.4465 - accuracy: 0.5259 - val_loss: 0.9026 - val_accuracy: 0.7080
# Epoch 3/100
# 84/84 - 5s - loss: 1.0334 - accuracy: 0.6623 - val_loss: 0.6751 - val_accuracy: 0.7734
# Epoch 4/100
# 84/84 - 6s - loss: 0.8536 - accuracy: 0.7186 - val_loss: 0.6234 - val_accuracy: 0.7757
# Epoch 5/100
# 84/84 - 5s - loss: 0.7288 - accuracy: 0.7562 - val_loss: 0.5066 - val_accuracy: 0.8225
# Epoch 6/100
# 84/84 - 5s - loss: 0.6681 - accuracy: 0.7758 - val_loss: 0.5265 - val_accuracy: 0.8211
# Epoch 7/100
# 84/84 - 5s - loss: 0.5796 - accuracy: 0.8052 - val_loss: 0.4289 - val_accuracy: 0.8612
# Epoch 8/100
# 84/84 - 5s - loss: 0.5445 - accuracy: 0.8169 - val_loss: 0.3872 - val_accuracy: 0.8717
# Epoch 9/100
# 84/84 - 5s - loss: 0.4944 - accuracy: 0.8306 - val_loss: 0.3357 - val_accuracy: 0.8836
# Epoch 10/100
# 84/84 - 5s - loss: 0.4685 - accuracy: 0.8434 - val_loss: 0.3883 - val_accuracy: 0.8657
# Epoch 11/100
# 84/84 - 5s - loss: 0.4565 - accuracy: 0.8422 - val_loss: 0.3697 - val_accuracy: 0.8761
# Epoch 12/100
# 84/84 - 4s - loss: 0.4186 - accuracy: 0.8624 - val_loss: 0.3205 - val_accuracy: 0.8906
# Epoch 13/100
# 84/84 - 5s - loss: 0.3886 - accuracy: 0.8697 - val_loss: 0.2743 - val_accuracy: 0.9163
# Epoch 14/100
# 84/84 - 5s - loss: 0.3970 - accuracy: 0.8653 - val_loss: 0.2997 - val_accuracy: 0.9089
# Epoch 15/100
# 84/84 - 5s - loss: 0.3665 - accuracy: 0.8775 - val_loss: 0.2736 - val_accuracy: 0.9137
# Epoch 16/100
# 84/84 - 5s - loss: 0.3618 - accuracy: 0.8777 - val_loss: 0.2950 - val_accuracy: 0.9033
# Epoch 17/100
# 84/84 - 5s - loss: 0.3571 - accuracy: 0.8787 - val_loss: 0.2427 - val_accuracy: 0.9226
# Epoch 18/100
# 84/84 - 6s - loss: 0.3250 - accuracy: 0.8903 - val_loss: 0.2543 - val_accuracy: 0.9200
# Epoch 19/100
# 84/84 - 5s - loss: 0.3099 - accuracy: 0.8924 - val_loss: 0.2319 - val_accuracy: 0.9219
# Epoch 20/100
# 84/84 - 5s - loss: 0.3030 - accuracy: 0.8994 - val_loss: 0.2403 - val_accuracy: 0.9222
# Epoch 21/100
# 84/84 - 5s - loss: 0.2852 - accuracy: 0.9052 - val_loss: 0.2216 - val_accuracy: 0.9327
# Epoch 22/100
# 84/84 - 5s - loss: 0.2863 - accuracy: 0.9069 - val_loss: 0.2472 - val_accuracy: 0.9148
# Epoch 23/100
# 84/84 - 5s - loss: 0.2677 - accuracy: 0.9111 - val_loss: 0.2086 - val_accuracy: 0.9319
# Epoch 24/100
# 84/84 - 5s - loss: 0.2558 - accuracy: 0.9168 - val_loss: 0.2063 - val_accuracy: 0.9386
# Epoch 25/100
# 84/84 - 5s - loss: 0.2541 - accuracy: 0.9120 - val_loss: 0.2046 - val_accuracy: 0.9330
# Epoch 26/100
# 84/84 - 5s - loss: 0.2388 - accuracy: 0.9213 - val_loss: 0.2068 - val_accuracy: 0.9349
# Epoch 27/100
# 84/84 - 5s - loss: 0.2357 - accuracy: 0.9200 - val_loss: 0.2162 - val_accuracy: 0.9315
# Epoch 28/100
# 84/84 - 5s - loss: 0.2446 - accuracy: 0.9189 - val_loss: 0.2136 - val_accuracy: 0.9330
# Epoch 29/100
# 84/84 - 5s - loss: 0.2309 - accuracy: 0.9221 - val_loss: 0.1713 - val_accuracy: 0.9520
# Epoch 30/100
# 84/84 - 5s - loss: 0.2243 - accuracy: 0.9243 - val_loss: 0.1947 - val_accuracy: 0.9435
# Epoch 31/100
# 84/84 - 5s - loss: 0.2102 - accuracy: 0.9284 - val_loss: 0.2134 - val_accuracy: 0.9301
# Epoch 32/100
- val_loss: 0.1261 - val_accuracy: 0.9621
# Epoch 91/100
# 84/84 - 5s - loss: 0.1003 - accuracy: 0.9698 - val_loss: 0.1261 - val_accuracy: 0.9621
# Epoch 92/100
# 84/84 - 5s - loss: 0.1003 - accuracy: 0.9687 - val_loss: 0.1261 - val_accuracy: 0.9621
# Epoch 93/100
# 84/84 - 5s - loss: 0.1028 - accuracy: 0.9658 - val_loss: 0.1261 - val_accuracy: 0.9621
# Epoch 94/100
# 84/84 - 5s - loss: 0.0983 - accuracy: 0.9691 - val_loss: 0.1261 - val_accuracy: 0.9621
# Epoch 95/100
# 84/84 - 5s - loss: 0.1059 - accuracy: 0.9669 - val_loss: 0.1261 - val_accuracy: 0.9621
# Epoch 96/100
# 84/84 - 5s - loss: 0.1052 - accuracy: 0.9651 - val_loss: 0.1261 - val_accuracy: 0.9621
# Epoch 97/100
# 84/84 - 5s - loss: 0.1062 - accuracy: 0.9681 - val_loss: 0.1261 - val_accuracy: 0.9621
# Epoch 98/100
# 84/84 - 5s - loss: 0.0997 - accuracy: 0.9688 - val_loss: 0.1261 - val_accuracy: 0.9621
# Epoch 99/100
# 84/84 - 5s - loss: 0.1026 - accuracy: 0.9690 - val_loss: 0.1261 - val_accuracy: 0.9621
# Epoch 100/100
# 84/84 - 5s - loss: 0.0991 - accuracy: 0.9701 - val_loss: 0.1261 - val_accuracy: 0.9621

# %% [markdown]
# ## Evaluation on Testing DataSet

# %%
test_labels = pd.read_csv('../input/arabic-hwr-ai-pro-intake1/test.csv')
test_images = Path(r'../input/arabic-hwr-ai-pro-intake1/test')

## read these all training images paths as Series
test_images_paths = pd.Series(sorted(list(test_images.glob(r'*.png'))), name='Filepath').astype(str)

test_images_paths.head()
# Out:
# 0    ../input/arabic-hwr-ai-pro-intake1/test/00000.png
# 1    ../input/arabic-hwr-ai-pro-intake1/test/00001.png
# 2    ../input/arabic-hwr-ai-pro-intake1/test/00002.png
# 3    ../input/arabic-hwr-ai-pro-intake1/test/00003.png
# 4    ../input/arabic-hwr-ai-pro-intake1/test/00004.png
# Name: Filepath, dtype: object

# %%
print('Number of Instances in test_set is', len(test_images_paths))
# Out:
# Number of Instances in test_set is 3360

# %%
test_full_set = np.empty((3360, 32, 32, 3), dtype=np.float32)  #take only the first 3 channels

for idx, path in enumerate(test_images_paths):
    img = plt.imread(path)
    img = img[:,:,:3]
    test_full_set[idx] = img
    
print('test_full_set.shape =>', test_full_set.shape)
# Out:
# test_full_set.shape => (3360, 32, 32, 3)

# %%
import scipy

# %%
labels = []
for m in models:
    predicts = np.argmax(m.predict(test_full_set), axis=1)
    labels.append(predicts)
    
# Ensemble with voting
labels = np.array(labels)
labels
# Out:
# array([[26, 10,  1, ...,  4, 11, 20],
#        [26, 10,  1, ...,  4, 11, 20],
#        [26, 10,  1, ...,  4, 11, 20]])

# %%
# labels = np.transpose(labels)
labels = scipy.stats.mode(labels)[0]
labels
# Out:
# array([[26, 10,  1, ...,  4, 11, 20]])

# %%
labels = np.squeeze(labels)
labels
# Out:
# array([26, 10,  1, ...,  4, 11, 20])

# %%
test_labels['label'] = labels

# %%
test_labels
# Out:
#         id  label
# 0        0     26
# 1        1     10
# 2        2      1
# 3        3     10
# 4        4     15
# ...    ...    ...
# 3355  3355     16
# 3356  3356      6
# 3357  3357      4
# 3358  3358     11
# 3359  3359     20
#
# [3360 rows x 2 columns]

# %%
test_labels[['id', 'label']].to_csv('/kaggle/working/submission.csv', index=False)
